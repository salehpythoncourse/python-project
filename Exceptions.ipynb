# %%
print(x) # handling the errors/exceptions

print('hi') # will not excecute
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-afb230c3840b> in <module>()
# ----> 1 print(x) # handling the errors/exceptions
#       2
#       3 print('hi') # will not excecute
#
# NameError: name 'x' is not defined

# %%
try:
  print("hi")
  print(x)
except:
  print("An exception occurred")
# Out:
# hi
# An exception occurred

# %%
try:
  print(x)
except: # if an error occured
  print("Something went wrong")
else:
  print("Nothing went wrong")

  
print('hi')
# Out:
# c
# Nothing went wrong
# hi

# %%
try:
  print(x)
  # print('hi')
except:
  print("Something went wrong")
finally:
  print("The 'try except' blocks is finished")
# Out:
# Something went wrong
# The 'try except' blocks is finished

# %%
try:
  f = open("demofile.txt") 
  try:
    f.write("Test test")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")
# Out:
# Something went wrong when writing to the file

# %%
try:
  age = int(input('please enter your age'))
except: 
  print('pls try again and enter a numbre as your age')
  age = int(input('please enter your age'))

result = age + 5
print('This is your age after 5 years' + str(result))
# Out:
# please enter your agesa
# pls try again and enter a numbre as your age
# please enter your age30
# This is your age after 5 years35

# %%
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-2edc57024fbc> in <module>()
#       2
#       3 if x < 0:
# ----> 4   raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %%
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed here")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c5afaeedfc27> in <module>()
#       2
#       3 if not type(x) is int:
# ----> 4   raise TypeError("Only integers are allowed here")
#
# TypeError: Only integers are allowed here
